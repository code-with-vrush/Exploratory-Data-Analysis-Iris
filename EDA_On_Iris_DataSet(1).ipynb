# %% [markdown]
#  <center>
#   </center>
#
# >  <h1><u>EDA ON IRIS DATASET</u><h1>
#
#   <center>
#  <img src="https://media.geeksforgeeks.org/geeksforgeeks/PerformEDAUsingIRISDataset/EDAUsingIRISDataset20220412131603.jpg"   width="90%" height="30%">
#  </center>
#
# #<span style='font-size:80px;'>&#9734;</span><u>what is EDA</u>?
#
# <p><span style='font-size:50px;'>&#8618;</span><b>Exploratory data analysis (EDA)</b> is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods.
#
# EDA helps determine how best to manipulate data sources to get the answers you need, making it easier for data scientists to discover patterns, spot anomalies, test a hypothesis, or check assumptions.
#
# EDA is primarily used to see what data can reveal beyond the formal modeling or hypothesis testing task and provides a provides a better understanding of data set variables and the relationships between them. It can also help determine if the statistical techniques you are considering for data analysis are appropriate. Originally developed by American mathematician John Tukey in the 1970s, EDA techniques continue to be a widely used method in the data discovery process today.</P>
#
#
# ---
#
#
# > <h2>&#9734;  <u><b>IRIS flower pic</b></u></h2>
#
# <center>
#  <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSKQpHRLGmEwrVo9zIpiE-qNdE2hTm7B4hLNA&s" alt="Girl in a jacket"  width="40%" height="20%">
# </center>
#
#
#
#
# <P><span style='font-size:50px;'>&#8618;</span><b>The</b> Iris dataset, introduced by the British biologist and statistician Ronald Fisher in 1936, is a quintessential dataset in the field of machine learning and statistics. It includes 150 observations of iris flowers with four features recorded for each observation: sepal length, sepal width, petal length, and petal width. Each observation is categorized into one of three species: Iris setosa, Iris versicolor, and Iris virginica. This dataset serves as an ideal starting point for demonstrating various statistical and machine learning techniques due to its simplicity and the distinct separations between its classes.</p>
# <center>
#
#
# </center>
#
# <p><span style='font-size:50px;'>&#8618;</span><b>In</b> this Exploratory Data Analysis (EDA), we will investigate the Iris dataset to uncover hidden patterns and relationships through visualizations and statistical summaries. By examining the distribution of features, identifying correlations, and distinguishing the different species based on their measurements, we aim to gain a deeper understanding of the data and its underlying structure.</p>
# <br>
# <br
#
#
# ---
#
# #<span style='font-size:80px;'>&#9734;</span><u>what is Python</u>?
#
#
#
# <span style='font-size:50px;'>&#8618;</span><b>Python</b> is the multipurpose interpreted language with the clear structure and hierarchy of syntax. It was invented by Guido van Rossum in 1991 and it aims at being understandable, with a stress on code readability, requiring features, and fewer lines of code to maintain it. Concerning the programming paradigms Python supports, one ought to know that it supports procedural, object oriented, and functional programming. Another important feature of the language is the given real-time availability of dynamic typing where the variable type does not have given type and is defined during the program’s execution. This makes Python quite flexible and also it is easy to write Python programs. It also has a large set of standard libraries that is ready made constructions and procedures needed to accomplish certain tasks like File and system Input/Output, Internet services processing of data etc Python is applied in number systems like web development, numerical computing data analysis artificial intelligence automation etc. For these reasons, efficiency and practicability, it has emerged as one of the most employed frameworks of developers for prototyping as well as subsequent implementation. Also, it has a large number of followers that contribute to improving the language itself, which also actively replenishes the third-party libraries and frameworks to expand its functionality.
#
#
# ```
# #here is example of python code:-
#         print("hello python")
# ```
# ---
# #<span style='font-size:80px;'>&#9734;</span><u>what is Pandas in Python</u>?
#
# <span style='font-size:50px;'>&#8618;</span><b>Pandas</b> is a data manipulation and analysis library for the programming language of Python that aims to become perfect and quick to handle data tables and similar structures. It provides two primary data structures: DataFrame and Series: both of them are two data containers in the Panda Library that are used to store the dated data. Whereas, a DataFrame is flexible in terms of size and number of columns and rows as well as the type of data being held in it and the data can be accessed using referencing through row and column names while, Series is a one-dimensional single array with varied types of data and the referencing of the data is done through its label.
#
# Pandas contains many data manipulation operations including merge/join the given datasets, reshape the data and group by operation for an aggregation. It also contains the sound data preprocessing features including handling of the missing data, filtering and type conversion. As well, the computation with time series is another one of the strong sides of the Pandas, because the library has specific functions that are useful for resampling the data, shift the time, use the rolling windows. They include operations that allow one to conveniently read from and write to various formats such as CSV, Excel, SQL, and JSON.
#
# Pandas seamlessly integrates well with the packages that exist on Python with regard to data analysis these include; NumPy which is efficient in numerical calculation, Matplotlib which is efficient in data visualization and SciPy which is efficient in general computation in science and engineering. Due to this, it remains among the most crucial functions as data pre-processing, cleaning, visualization, and even modeling.
#
#
# <h3><u>Characteristics of pandas</U>:-</h3>
#
# <p><dl>
# <b><dt>&#8226; Dataframe</dt></b></b>
#   <dd><span style='font-size:50px;'>&#8618;</span>Pandas comes with a data structure called a DataFrame, which is a two-dimensional labeled data structure with different colors (similar to a spreadsheet or SQL table) This makes it easy to index, slice, and manipulation data.</dd><br>
#
#   <b><dt>&#8226; Sequence</dt></b>
#   <dd>Beside the DataFrame, Pandas also provides a Series, which is a single labeled section that can hold any type of data (integer, string, float, Python objects, etc.) Series are the building blocks of DataFrames, representing characters.</dd><br>
#
#   <b><dt>&#8226; Data management</dt></b>
#   <dd><span style='font-size:50px;'>&#8618;</span>Pandas provides powerful tools for reorganizing, merging, slicing, indexing, and transforming data sets. It allows actions such as groupby, pivot tables, and exchanging data size in different ways.</dd><br>
#
#   <b><dt>&#8226; Used data missing</dt></b>
#   <dd><span style='font-size:50px;'>&#8618;</span>Pandas provides powerful tools for handling missing data, allowing users to fill in missing data (fillna()), drop missing data (dropna()), or missing values (interpolate()) enter.</dd><br>
#
#   <b><dt>&#8226; Input/Output</dt></b>
#   <dd><span style='font-size:50px;'>&#8618;</span>Pandas supports reading and writing data from a variety of file formats including CSV, Excel, SQL databases, JSON, and more. This simplifies data access and export operations.</dd><br>
#
#   <b><dt>&#8226; Time Series Data</dt></b>
#   <dd><span style='font-size:50px;'>&#8618;</span>Pandus provides powerful tools for working with time series data, including date range generation, shifting, backtracking, and resampling.</dd><br>
#
#   <b><dt>&#8226; Caution</dt></b>
#   <dd><span style='font-size:50px;'>&#8618;</span>While primarily a data manipulation library, Pandas integrates well with visual libraries such as Matplotlib and Seaborn to allow users to create quick plots and visualizations of their data.</dd><br>
# </dl></P>
#
#
#
# ---
# #<span style='font-size:80px;'>&#9734;</span><u>what is Seaborn in Python</u>?
# <p>Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. Seaborn is built on top of matplotlib and closely integrated with pandas data structures, making it particularly useful for statistical data visualization in Python.</p>
#
# <h3><u>Characteristics of Seaborn</U>:-</h3>
# <dl>
# <b><dt>&#8226; Statistical Plotting</dt></b>
# <dd>Seaborn simplifies the creation of complex statistical plots with concise syntax. It provides functions for easily creating visualizations such as scatter plots, bar plots, box plots, violin plots, and more.</dd><br>
#
# <b><dt>&#8226; Integration with Pandas</dt></b>
# <dd>Seaborn works seamlessly with pandas DataFrames and Series, allowing for direct plotting of data without extensive preprocessing.</dd><br>
#
# <b><dt>&#8226; Built-in Themes and Color Palettes</dt></b>
# <dd>Seaborn comes with built-in themes for styling matplotlib graphics to improve readability and aesthetics. It also provides a variety of color palettes for creating visually appealing plots.</dd><br>
#
# <b><dt>&#8226; Advanced Features</dt></b>
# <dd>Seaborn offers advanced features for statistical estimation and visualization, including categorical data plotting (like catplot()), linear regression models (lmplot()), matrix plots (heatmap()), and more complex visualizations.</dd><br>
#
# <b><dt>&#8226; Flexibility</dt></b>
# <dd>While Seaborn provides a high-level interface for creating plots quickly, it also allows for customization and tweaking of plot aesthetics and properties using matplotlib functionalities.</dd><br>
# </dl>
#
#
# ---

# %% [markdown]
# # **1)*Importing Libraries and Read Iris DataSet***
# # <span style='font-size:10px;'>&#9734;</span>here we import IRIS dataset uisng API</u>

# %%
import pandas as pd

# Load the Iris dataset
iris_df = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

# Display the dataset to understand its structure (optional)
print(iris_df)

# Query to filter the species and get only 3 rows for each
filtered_df = iris_df[iris_df['species'].isin(['setosa', 'versicolor', 'virginica'])]

# Show the first 3 rows for each species
result = filtered_df.groupby('species').head(3)

result

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so
import matplotlib.animation as animation
from mpl_toolkits.mplot3d import Axes3D
#import IRIS dataset uisng AP
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df)
iris_df.query('species == ["setosa","versicolor","virginica"]')[1:149]
#iris_df.query('species == "virginica"')[1:5]

# %% [markdown]
# # **2)*Data Pre-processing & Cleaning***
# 1.   Hed( );
# 2.   Teal( );

# %% [markdown]
# # **1.	Head( );**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import IRIS dataset uisng AP
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.head())
iris_df.head()

# %% [markdown]
# # **2.	Tail( );**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import IRIS dataset uisng AP
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.tail())

# %% [markdown]
# # **3.	Info( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.info())

# %% [markdown]
# # **4.	Describe( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.describe())

# %% [markdown]
# # **5.	Shape( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.shape)

# %% [markdown]
# # **6.	Isnull( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.isnull().sum())

# %% [markdown]
# # **7.	Unique( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")
print("unique Of species:-")
print(iris_df['species'].unique())
print("\nunique Of petal_length:-")
print(iris_df['petal_length'].unique())
print("\nunique Of petal_width:-")
print(iris_df['petal_width'].unique())
print("\nunique Of sepal_length:-")
print(iris_df['sepal_length'].unique())
print("\nunique Of sepal_width:-")
print(iris_df["sepal_width"].unique())

# %% [markdown]
# # **8.	Creating group using groupby( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

grouped = iris_df.groupby('species')[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

result = grouped.apply(lambda x: x)

print(result)

# %% [markdown]
# # **9.	max( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.max())

# %% [markdown]
# # **10.	min( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.min())

# %% [markdown]
# # **11.	Sum of all data in numeric**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].sum(axis=0))

# %% [markdown]
# # **12.	Value_count( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.value_counts("species"))

# %% [markdown]
# # **13.	corr( );**

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

print(iris_df.corr(numeric_only=True))

# %% [markdown]
# <h1>herev is a Graph work of iris DataSet</h1>

# %%
iris_df=pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

sns.countplot(x='species', data=iris_df)
plt.xlabel('Species')
plt.ylabel('Count')
plt.title('Distribution of Species')
plt.show()

# %%
iris_df['species'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title("Iris Species Distribution")
plt.ylabel('')
plt.show()

# %%
sns.pairplot(data=iris_df, hue="species",palette="YlGnBu_r")
plt.show()

# %%
plt.figure(figsize=(15,20))

sns.heatmap(iris_df.select_dtypes(include=['number']).corr(), annot=True, fmt='.2f', cmap='Pastel2', linewidths=2)

plt.title('Correlation Heatmap')
plt.show()

# %%
# Load the iris dataset
iris_df = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")
iris_df.hist(edgecolor='white', linewidth=3, figsize=(10, 10), color='skyblue')
plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid", rc={'axes.facecolor':'white'})
sns.set_palette("bright")
sns.relplot(
    data=iris_df,
    x="sepal_length", y="petal_length", hue="species",
    kind="line"
)

# %%
g=sns.relplot(
    data=iris_df, kind="line",
    x="sepal_width", y="petal_width", hue="species", style="species",
    col="species",
    height=5,
    palette="crest"
)
g.set_titles("{col_name} species")
g.set_axis_labels("Sepal Length", "Petal Length")
g.add_legend()
plt.show()

# %%
sns.catplot(
    data=iris_df, x="sepal_length", y="sepal_width", hue="species",
    palette={"versicolor": "g", "virginica": "m", "setosa":"b"},
    markers=["^", "o", "*"],
    linestyles=["-", "--", ":"],
    kind="point",
    height=6,
    aspect=2.5
)

# %%
# Box plots for each feature by species
plt.figure(figsize=(12, 8))
sns.boxplot(data=iris_df, orient="h", palette="crest")
plt.title("Distribution of Iris Features by Species", fontsize=16)
plt.xlabel("Feature Values", fontsize=14)
plt.ylabel("Features", fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
sns.jointplot(data=iris_df, x="sepal_length", y="petal_length", hue="species")

plt.show()

# %%
# Pair Grid with different plot types
g = sns.PairGrid(iris_df, hue="species", palette="crest")
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)
g.add_legend()
plt.subplots_adjust(top=0.95)
g.fig.suptitle("Pair Grid with different of plot types", fontsize=16)
plt.show()

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Adjust space between plots
plt.subplots_adjust(hspace=0.4, wspace=0.4)

# Violin plot for Sepal Length
sns.violinplot(ax=axes[0, 0], x='species', y='sepal_length', data=iris_df, palette="crest")
axes[0, 0].set_title('Violin plot of Sepal Length by Species')

# Violin plot for Sepal Width
sns.violinplot(ax=axes[0, 1], x='species', y='sepal_width', data=iris_df, palette="crest")
axes[0, 1].set_title('Violin plot of Sepal Width by Species')

# Violin plot for Petal Length
sns.violinplot(ax=axes[1, 0], x='species', y='petal_length', data=iris_df, palette="crest")
axes[1, 0].set_title('Violin plot of Petal Length by Species')

# Violin plot for Petal Width
sns.violinplot(ax=axes[1, 1], x='species', y='petal_width', data=iris_df, palette="crest")
axes[1, 1].set_title('Violin plot of Petal Width by Species')

# Display the plots
plt.show()

# %%
p = (
    so.Plot(iris_df, x="petal_length", y="petal_width", color="species")
    .facet(col="species")
    .add(so.Dots(), so.Jitter(0.10))
    .label(
        x="Petal Length",
        y="Petal Width"
    )
    .layout(size=(15,6))
)
p.show()

# %%
# Create a 3D scatter plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Set colors and markers
colors = {'setosa': 'red', 'versicolor': 'green', 'virginica': 'blue'}
markers = {'setosa': 'o', 'versicolor': '^', 'virginica': 's'}

# Plot each species with different colors and markers
for species in iris_df['species'].unique():
    subset = iris_df[iris_df['species'] == species]
    ax.scatter(subset['sepal_length'], subset['sepal_width'], subset['petal_length'],
               color=colors[species], marker=markers[species], label=species, s=100)

# Add labels and legend
ax.set_xlabel('Sepal Length')
ax.set_ylabel('Sepal Width')
ax.set_zlabel('Petal Length')
ax.legend()

plt.title('3D Scatter Plot of Iris Dataset')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 5))
# Animation function
def animate(i):
    ax.clear()  # Clear the axis for each frame
    sns.scatterplot(data=iris_df, x='sepal_length', y='petal_length', hue='species', ax=ax, palette='crest', legend=False)
    sns.kdeplot(data=iris_df[:i], x='sepal_length', y='petal_length', ax=ax, fill=True, alpha=0.3)
    ax.set_title(f'Frame {i+1}/{len(iris_df)}')

# Create the animation
ani = animation.FuncAnimation(fig, animate, frames=len(iris_df), interval=100, repeat=False)
# Save the animation
ani.save('simple_animated_plot.mp4', writer='ffmpeg', fps=15)
# Show the plot
plt.show()

# %%
import pandas as pd
import plotly.express as px

# Load the iris dataset
iris_df = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

# 3D Scatter plot
fig = px.scatter_3d(iris_df, x='sepal_length', y='sepal_width', z='petal_length',
                    color='species', symbol='species', size='petal_width',
                    title='3D Scatter Plot of Iris Dataset')

fig.show()
